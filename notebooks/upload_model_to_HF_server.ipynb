# %%
pip install huggingface_hub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\HP\Desktop\drug_safety_insights_nlp\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from huggingface_hub import login
login()

# %%
from transformers import AutoModelForTokenClassification, AutoTokenizer

model = AutoModelForTokenClassification.from_pretrained("../models/biobert_ner/checkpoint-3939")
tokenizer = AutoTokenizer.from_pretrained("../models/biobert_ner/checkpoint-3939")
# Push to hub — replace with your HuggingFace username
model.push_to_hub("Sakshi0106/biobert-drug-adr-ner")
tokenizer.push_to_hub("Sakshi0106/biobert-drug-adr-ner")

print("Model pushed to HuggingFace Hub")
# Out:
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# README.md: 0.00B [00:00, ?B/s]
# Model pushed to HuggingFace Hub
